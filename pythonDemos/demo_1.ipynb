# %% [markdown]
# ### Demo plots using FunAODs using upROOT and Coffea
#
# Trying out upROOT and Coffea to test out FunAODs from miniAODs and AODs

# %%
import uproot as rt
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import awkward as ak
